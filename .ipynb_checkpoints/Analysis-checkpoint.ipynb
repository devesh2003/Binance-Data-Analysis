# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
asset = "APEUSDT"
timeframe = "15m"
date = "2022-12-13"
name = [asset,timeframe,date]

# %%
file = "-".join(name)+".csv"

# %%
df = pd.read_csv(file)
df.columns = ["Open Time","Open","High","Low","Close","Volume","Close Time",
             "Quote asset volumne","Total Trades","Buyer Base Volume",
             "Taker buy quote asset volume","Ignore"]

# %%
df.head()
# Out:
#        Open Time   Open   High    Low  Close    Volume     Close Time  \
# 0  1670890500000  4.354  4.357  4.319  4.319  97197.80  1670891399999
# 1  1670891400000  4.319  4.351  4.315  4.334  70430.22  1670892299999
# 2  1670892300000  4.333  4.345  4.323  4.338  40885.58  1670893199999
# 3  1670893200000  4.338  4.343  4.322  4.330  30509.61  1670894099999
# 4  1670894100000  4.332  4.332  4.294  4.319  72925.73  1670894999999
#
#    Quote asset volumne  Total Trades  Buyer Base Volume  \
# 0         421475.73586          1318           53957.52
# 1         305099.80746           907           53192.17
# 2         177202.92164           508           26376.29
# 3         132162.75351           555           14746.44
# 4         314654.01220          1032           28123.94
#
#    Taker buy quote asset volume  Ignore
# 0                  234007.85422       0
# 1                  230392.73604       0
# 2                  114371.28540       0
# 3                   63913.01194       0
# 4                  121415.81922       0

# %%
df = df[["Open","High","Low","Close","Volume","Total Trades","Buyer Base Volume","Taker buy quote asset volume"]]
df["Change"] = (df["Close"] - df["Open"])*100/df["Open"] 
df["Next Change"] = df["Change"].shift(-1) 
df["Buyer Volume Change"] = (df["Buyer Base Volume"] - df["Buyer Base Volume"].shift(1))*100 /df["Buyer Base Volume"].shift(1)

# %%
df.head()
# Out:
#     Open   High    Low  Close    Volume  Total Trades  Buyer Base Volume  \
# 0  4.354  4.357  4.319  4.319  97197.80          1318           53957.52
# 1  4.319  4.351  4.315  4.334  70430.22           907           53192.17
# 2  4.333  4.345  4.323  4.338  40885.58           508           26376.29
# 3  4.338  4.343  4.322  4.330  30509.61           555           14746.44
# 4  4.332  4.332  4.294  4.319  72925.73          1032           28123.94
#
#    Taker buy quote asset volume    Change  Next Change  Buyer Volume Change
# 0                  234007.85422 -0.803859     0.347303                  NaN
# 1                  230392.73604  0.347303     0.115393            -1.418431
# 2                  114371.28540  0.115393    -0.184417           -50.413209
# 3                   63913.01194 -0.184417    -0.300092           -44.092061
# 4                  121415.81922 -0.300092    -0.231589            90.716810

# %%
df[ df["Next Change"] > 0.5 ]
# Out:
#      Open   High    Low  Close     Volume  Total Trades  Buyer Base Volume  \
# 31  3.950  3.963  3.929  3.961   98467.55          1536           53634.16
# 34  3.990  3.998  3.971  3.987  110294.96          1440           59351.27
# 37  4.058  4.063  4.038  4.041  100423.41          1315           54824.63
# 52  4.076  4.117  4.047  4.077  201195.90          2790          116500.68
# 54  4.129  4.159  4.118  4.134  176234.65          1973           91898.43
# 58  4.148  4.163  4.136  4.155   92097.32          1116           43667.95
# 69  3.986  4.005  3.980  3.991  165928.26          1807          112188.56
# 70  3.992  4.017  3.992  4.014  123938.08          1430           63989.51
# 81  4.064  4.081  4.061  4.080   27904.93           424           18984.67
#
#     Taker buy quote asset volume    Change  Next Change  Buyer Volume Change
# 31                  211900.81779  0.278481     0.681646            10.552389
# 34                  236500.87972 -0.075188     1.329320           -54.175556
# 37                  222235.24868 -0.418926     0.890648           -37.064515
# 52                  475882.62694  0.024534     1.225791            84.005164
# 54                  380201.27426  0.121095     0.604887           -57.704820
# 58                  181380.24622  0.168756     0.529483           -25.559591
# 69                  448227.40112  0.125439     0.551102           -33.228361
# 70                  255967.67171  0.551102     1.420030           -42.962536
# 81                   77325.03742  0.393701     0.539084           -49.826524

# %%
plt.scatter( df["Taker buy quote asset volume"],df["Next Change"] )
# plt.plot(x,y)
